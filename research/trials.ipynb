# %%
import os

# %%
dict = {
      "key1": "value1"
}

# %%
dict['key1']
# Out:
# 'value1'

# %%
from box.config_box import ConfigBox

# %%
dict = ConfigBox({
      "key1": "value1"
})

# %%
dict.key1
# Out:
# 'value1'

# %%
from ensure import ensure_annotations

# %%
def add(a:int, b:int) -> int:
      return a * b

# %%
add(5, 5)
# Out:
# 25

# %%
add(5, "5")
# Out:
# '55555'

# %%
@ensure_annotations
def add(a:int, b:int) -> int:
      return a * b

# %%
add(5, 5)
# Out:
# 25

# %%
add(5, "5")
# Out:
# ---------------------------------------------------------------------------
# EnsureError                               Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 add(5, "5")
#
# File d:\Machine Learning\VisaEligibilityPredictor-AU\env\Lib\site-packages\ensure\main.py:870, in WrappedFunctionReturn.__call__(self, *args, **kwargs)
#     868     if not isinstance(value, templ):
#     869         msg = "Argument {arg} of type {valt} to {f} " "does not match annotation type {t}"
# --> 870         raise EnsureError(msg.format(arg=arg, f=self.f, t=templ, valt=type(value)))
#     872 return_val = self.f(*args, **kwargs)
#     873 if not isinstance(return_val, self.return_templ):
#
# EnsureError: Argument b of type <class 'str'> to <function add at 0x000002BB12FC63E0> does not match annotation type <class 'int'>
